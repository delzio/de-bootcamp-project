# %%
import pyspark
from pyspark.sql import SparkSession, Row
from pyspark.conf import SparkConf
from pyspark.context import SparkContext
from pyspark.sql.window import Window
import pyspark.sql.functions as F
import pyspark.sql.types as T
from datetime import datetime, timedelta, timezone
from airflow.providers.google.cloud.operators.bigquery import BigQueryCreateExternalTableOperator
import os
import subprocess
import joblib
import pandas as pd
from chemotools.baseline import LinearCorrection
from chemotools.smooth import SavitzkyGolayFilter
from chemotools.derivative import NorrisWilliams
from chemotools.feature_selection import RangeCut
from sklearn.preprocessing import StandardScaler

# %%
# Get GCP input data
PROJECT_ID = 'intricate-reef-411403'
BUCKET = "test_bucket-intricate-reef-41103"
PROJECT_HOME = os.getenv("HOME")+"/data-engineering-zoomcamp/project" # this may need to be updated when dockerized
credentials_location = PROJECT_HOME+"/.google/credentials/gcp.json"

# Get file structure data
local_data_path = "/.project/data/raw/Mendeley_data/" # this will need to change when dockerized
temp_path = "/.project/data/raw/temp/"
local_data_file = "100_Batches_IndPenSim_V3.csv"
path_to_local_home = os.environ.get("AIRFLOW_HOME", "/opt/airflow/")
gcs_input_path = "raw/"
gcs_output_path = "processed/raman_context/"
spark_jar_path = f"{PROJECT_HOME}/lib/gcs-connector-hadoop3-2.2.5.jar,{PROJECT_HOME}/lib/spark-3.5-bigquery-0.37.0.jar"

# Get PLS Model
model_path = PROJECT_HOME+"/data/processed/model/raman_pls_model.pk1"
pls_model = joblib.load(model_path)

# %%
# start spark standalone instance with worker
start_spark_master = "cd $SPARK_HOME && ./sbin/start-master.sh --port 7078"
start_spark_worker = "cd $SPARK_HOME && ./sbin/start-worker.sh spark://127.0.0.1:7078"

start_master_process = subprocess.Popen(start_spark_master, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
start_master_output, start_master_error = start_master_process.communicate()

start_worker_process = subprocess.Popen(start_spark_worker, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
start_worker_output, start_worker_error = start_worker_process.communicate()

# %%
# define spark configuration
conf = SparkConf() \
    .setMaster("spark://127.0.0.1:7078") \
    .setAppName("predict_concentration_data") \
    .set("spark.jars", spark_jar_path) \
    .set("spark.hadoop.google.cloud.auth.service.account.enable", "true") \
    .set("spark.executor.memory","4g") \
    .set("spark.hadoop.google.cloud.auth.service.account.json.keyfile", credentials_location)

# %%
# set up spark context
sc = SparkContext(conf=conf)

hadoop_conf = sc._jsc.hadoopConfiguration()

hadoop_conf.set("fs.AbstractFileSystem.gs.impl",  "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")
hadoop_conf.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
hadoop_conf.set("fs.gs.auth.service.account.json.keyfile", credentials_location)
hadoop_conf.set("fs.gs.auth.service.account.enable", "true")
# Out:
# 24/04/14 23:04:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# Start Spark session using standalone cluster
spark = SparkSession.builder \
    .config(conf=sc.getConf()) \
    .getOrCreate()

# %%
# find most recent existing record in T_RAMAN_PREDICTION
# gather all raman records produced in the last 5 minutes
#current_time = datetime.utcnow()
current_time = "2024-04-14 10:08:55"
current_time = datetime.strptime(current_time, "%Y-%m-%d %H:%M:%S")
back_time = current_time - timedelta(minutes=7)
current_ts = current_time.strftime("%Y-%m-%d %H:%M:%S")
back_ts = back_time.strftime("%Y-%m-%d %H:%M:%S")
date_range = (current_ts,back_ts)
where_clause = """sample_ts BETWEEN TO_TIMESTAMP('{1}','yyyy-MM-dd HH:mm:ss') AND TO_TIMESTAMP('{0}','yyyy-MM-dd HH:mm:ss')""".format(*date_range)
try:
    most_recent_prediction = spark.read.format("bigquery") \
            .option("project",PROJECT_ID) \
            .option("dataset","test_schema") \
            .option("table","t_raman_prediction") \
            .load() \
            .where(where_clause) \
            .agg(F.max("sample_ts")) \
            .collect()[0][0]
    print(f"Some existing records found - starting after most recent existing prediction time")
except Exception as e:
    print(f"No existing records found within 7 minutes of current time")
    most_recent_prediction = back_time
most_recent_ts = most_recent_prediction.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# No existing records found within 7 minutes of current time

# %%
# Gather New context data that has not been traced into T_RAMAN_PREDICTION
date_range = (current_ts,most_recent_ts)
where_clause = """sample_ts BETWEEN TO_TIMESTAMP('{1}','yyyy-MM-dd HH:mm:ss') AND TO_TIMESTAMP('{0}','yyyy-MM-dd HH:mm:ss')""".format(*date_range)
raman_context_ids = spark.read.format("bigquery") \
        .option("project",PROJECT_ID) \
        .option("dataset","test_schema") \
        .option("table","t_sample_context") \
        .load() \
        .select(["id","penicillin_concentration_g_l"]) \
        .where(where_clause)

# %%
# Join to Raman Spectra Data
# Gather raw data
df_raw_values = spark.read.parquet('gs://test_bucket-intricate-reef-41103/raw/*.parquet')
# filter columns
raman_cols = ["id"]
raman_cols.extend([str(i) for i in list(range(689,2089)[::-1])])
# separate raw df into relevant raman measurement data
df_raman = df_raw_values.select(raman_cols) \
    .withColumnRenamed("id","id_raman")
# join to raman_context_ids to filter out old data
df_raman_new = df_raman.join(raman_context_ids, df_raman.id_raman == raman_context_ids.id, "inner").drop("id_raman")

# %%
df_raman_new.printSchema()
# Out:
# root
#  |-- 2088: double (nullable = true)
#  |-- 2087: double (nullable = true)
#  |-- 2086: double (nullable = true)
#  |-- 2085: double (nullable = true)
#  |-- 2084: double (nullable = true)
#  |-- 2083: double (nullable = true)
#  |-- 2082: double (nullable = true)
#  |-- 2081: double (nullable = true)
#  |-- 2080: double (nullable = true)
#  |-- 2079: double (nullable = true)
#  |-- 2078: double (nullable = true)
#  |-- 2077: double (nullable = true)
#  |-- 2076: double (nullable = true)
#  |-- 2075: double (nullable = true)
#  |-- 2074: double (nullable = true)
#  |-- 2073: double (nullable = true)
#  |-- 2072: double (nullable = true)
#  |-- 2071: double (nullable = true)
#  |-- 2070: double (nullable = true)
#  |-- 2069: double (nullable = true)
#  |-- 2068: double (nullable = true)
#  |-- 2067: double (nullable = true)
#  |-- 2066: double (nullable = true)
#  |-- 2065: double (nullable = true)
#  |-- 2064: double (nullable = true)
#  |-- 2063: double (nullable = true)
#  |-- 2062: double (nullable = true)
#  |-- 2061: double (nullable = true)
#  |-- 2060: double (nullable = true)
#  |-- 2059: double (nullable = true)
#  |-- 2058: double (nullable = true)
#  |-- 2057: double (nullable = true)
#  |-- 2056: double (nullable = true)
#  |-- 2055: double (nullable = true)
#  |-- 2054: double (nullable = true)
#  |-- 2053: double (nullable = true)
#  |-- 2052: double (nullable = true)
#  |-- 2051: double (nullable = true)
#  |-- 2050: double (nullable = true)
#  |-- 2049: double (nullable = true)
#  |-- 2048: double (nullable = true)
#  |-- 2047: double (nullable = true)
#  |-- 2046: double (nullable = true)
#  |-- 2045: double (nullable = true)
#  |-- 2044: double (nullable = true)
#  |-- 2043: double (nullable = true)
#  |-- 2042: double (nullable = true)
#  |-- 2041: double (nullable = true)
#  |-- 2040: double (nullable = true)
#  |-- 2039: double (nullable = true)
#  |-- 2038: double (nullable = true)
#  |-- 2037: double (nullable = true)
#  |-- 2036: double (nullable = true)
#  |-- 2035: double (nullable = true)
#  |-- 2034: double (nullable = true)
#  |-- 2033: double (nullable = true)
#  |-- 2032: double (nullable = true)
#  |-- 2031: double (nullable = true)
#  |-- 2030: double (nullable = true)
#  |-- 2029: double (nullable = true)
#  |-- 2028: double (nullable = true)
#  |-- 2027: double (nullable = true)
#  |-- 2026: double (nullable = true)
#  |-- 2025: double (nullable = true)
#  |-- 2024: double (nullable = true)
#  |-- 2023: double (nullable = true)
#  |-- 2022: double (nullable = true)
#  |-- 2021: double (nullable = true)
#  |-- 2020: double (nullable = true)
#  |-- 2019: double (nullable = true)
#  |-- 2018: double (nullable = true)
#  |-- 2017: double (nullable = true)
#  |-- 2016: double (nullable = true)
#  |-- 2015: double (nullable = true)
#  |-- 2014: double (nullable = true)
#  |-- 2013: double (nullable = true)
#  |-- 2012: double (nullable = true)
#  |-- 2011: double (nullable = true)
#  |-- 2010: double (nullable = true)
#  |-- 2009: double (nullable = true)
#  |-- 2008: double (nullable = true)
#  |-- 2007: double (nullable = true)
#  |-- 2006: double (nullable = true)
#  |-- 2005: double (nullable = true)
#  |-- 2004: double (nullable = true)
#  |-- 2003: double (nullable = true)
#  |-- 2002: double (nullable = true)
#  |-- 2001: double (nullable = true)
#  |-- 2000: double (nullable = true)
#  |-- 1999: double (nullable = true)
#  |-- 1998: double (nullable = true)
#  |-- 1997: double (nullable = true)
#  |-- 1996: double (nullable = true)
#  |-- 1995: double (nullable = true)
#  |-- 1994: double (nullable = true)
#  |-- 1993: double (nullable = true)
#  |-- 1992: double (nullable = true)
#  |-- 1991: double (nullable = true)
#  |-- 1990: double (nullable = true)
#  |-- 1989: double (nullable = true)
#  |-- 1988: double (nullable = true)
#  |-- 1987: double (nullable = true)
#  |-- 1986: double (nullable = true)
#  |-- 1985: double (nullable = true)
#  |-- 1984: double (nullable = true)
#  |-- 1983: double (nullable = true)
#  |-- 1982: double (nullable = true)
#  |-- 1981: double (nullable = true)
#  |-- 1980: double (nullable = true)
#  |-- 1979: double (nullable = true)
#  |-- 1978: double (nullable = true)
#  |-- 1977: double (nullable = true)
#  |-- 1976: double (nullable = true)
#  |-- 1975: double (nullable = true)
#  |-- 1974: double (nullable = true)
#  |-- 1973: double (nullable = true)
#  |-- 1972: double (nullable = true)
#  |-- 1971: double (nullable = true)
#  |-- 1970: double (nullable = true)
#  |-- 1969: double (nullable = true)
#  |-- 1968: double (nullable = true)
#  |-- 1967: double (nullable = true)
#  |-- 1966: double (nullable = true)
#  |-- 1965: double (nullable = true)
#  |-- 1964: double (nullable = true)
#  |-- 1963: double (nullable = true)
#  |-- 1962: double (nullable = true)
#  |-- 1961: double (nullable = true)
#  |-- 1960: double (nullable = true)
#  |-- 1959: double (nullable = true)
#  |-- 1958: double (nullable = true)
#  |-- 1957: double (nullable = true)
#  |-- 1956: double (nullable = true)
#  |-- 1955: double (nullable = true)
#  |-- 1954: double (nullable = true)
#  |-- 1953: double (nullable = true)
#  |-- 1952: double (nullable = true)
#  |-- 1951: double (nullable = true)
#  |-- 1950: double (nullable = true)
#  |-- 1949: double (nullable = true)
#  |-- 1948: double (nullable = true)
#  |-- 1947: double (nullable = true)
#  |-- 1946: double (nullable = true)
#  |-- 1945: double (nullable = true)
#  |-- 1944: double (nullable = true)
#  |-- 1943: double (nullable = true)
#  |-- 1942: double (nullable = true)
#  |-- 1941: double (nullable = true)
#  |-- 1940: double (nullable = true)
#  |-- 1939: double (nullable = true)
#  |-- 1938: double (nullable = true)
#  |-- 1937: double (nullable = true)
#  |-- 1936: double (nullable = true)
#  |-- 1935: double (nullable = true)
#  |-- 1934: double (nullable = true)
#  |-- 1933: double (nullable = true)
#  |-- 1932: double (nullable = true)
#  |-- 1931: double (nullable = true)
#  |-- 1930: double (nullable = true)
#  |-- 1929: double (nullable = true)
#  |-- 1928: double (nullable = true)
#  |-- 1927: double (nullable = true)
#  |-- 1926: double (nullable = true)
#  |-- 1925: double (nullable = true)
#  |-- 1924: double (nullable = true)
#  |-- 1923: double (nullable = true)
#  |-- 1922: double (nullable = true)
#  |-- 1921: double (nullable = true)
#  |-- 1920: double (nullable = true)
#  |-- 1919: double (nullable = true)
#  |-- 1918: double (nullable = true)
#  |-- 1917: double (nullable = true)
#  |-- 1916: double (nullable = true)
#  |-- 1915: double (nullable = true)
#  |-- 1914: double (nullable = true)
#  |-- 1913: double (nullable = true)
#  |-- 1912: double (nullable = true)
#  |-- 1911: double (nullable = true)
#  |-- 1910: double (nullable = true)
#  |-- 1909: double (nullable = true)
#  |-- 1908: double (nullable = true)
#  |-- 1907: double (nullable = true)
#  |-- 1906: double (nullable = true)
#  |-- 1905: double (nullable = true)
#  |-- 1904: double (nullable = true)
#  |-- 1903: double (nullable = true)
#  |-- 1902: double (nullable = true)
#  |-- 1901: double (nullable = true)
#  |-- 1900: double (nullable = true)
#  |-- 1899: double (nullable = true)
#  |-- 1898: double (nullable = true)
#  |-- 1897: double (nullable = true)
#  |-- 1896: double (nullable = true)
#  |-- 1895: double (nullable = true)
#  |-- 1894: double (nullable = true)
#  |-- 1893: double (nullable = true)
#  |-- 1892: double (nullable = true)
#  |-- 1891: double (nullable = true)
#  |-- 1890: double (nullable = true)
#  |-- 1889: double (nullable = true)
#  |-- 1888: double (nullable = true)
#  |-- 1887: double (nullable = true)
#  |-- 1886: double (nullable = true)
#  |-- 1885: double (nullable = true)
#  |-- 1884: double (nullable = true)
#  |-- 1883: double (nullable = true)
#  |-- 1882: double (nullable = true)
#  |-- 1881: double (nullable = true)
#  |-- 1880: double (nullable = true)
#  |-- 1879: double (nullable = true)
#  |-- 1878: double (nullable = true)
#  |-- 1877: double (nullable = true)
#  |-- 1876: double (nullable = true)
#  |-- 1875: double (nullable = true)
#  |-- 1874: double (nullable = true)
#  |-- 1873: double (nullable = true)
#  |-- 1872: double (nullable = true)
#  |-- 1871: double (nullable = true)
#  |-- 1870: double (nullable = true)
#  |-- 1869: double (nullable = true)
#  |-- 1868: double (nullable = true)
#  |-- 1867: double (nullable = true)
#  |-- 1866: double (nullable = true)
#  |-- 1865: double (nullable = true)
#  |-- 1864: double (nullable = true)
#  |-- 1863: double (nullable = true)
#  |-- 1862: double (nullable = true)
#  |-- 1861: double (nullable = true)
#  |-- 1860: double (nullable = true)
#  |-- 1859: double (nullable = true)
#  |-- 1858: double (nullable = true)
#  |-- 1857: double (nullable = true)
#  |-- 1856: double (nullable = true)
#  |-- 1855: double (nullable = true)
#  |-- 1854: double (nullable = true)
#  |-- 1853: double (nullable = true)
#  |-- 1852: double (nullable = true)
#  |-- 1851: double (nullable = true)
#  |-- 1850: double (nullable = true)
#  |-- 1849: double (nullable = true)
#  |-- 1848: double (nullable = true)
#  |-- 1847: double (nullable = true)
#  |-- 1846: double (nullable = true)
#  |-- 1845: double (nullable = true)
#  |-- 1844: double (nullable = true)
#  |-- 1843: double (nullable = true)
#  |-- 1842: double (nullable = true)
#  |-- 1841: double (nullable = true)
#  |-- 1840: double (nullable = true)
#  |-- 1839: double (nullable = true)
#  |-- 1838: double (nullable = true)
#  |-- 1837: double (nullable = true)
#  |-- 1836: double (nullable = true)
#  |-- 1835: double (nullable = true)
#  |-- 1834: double (nullable = true)
#  |-- 1833: double (nullable = true)
#  |-- 1832: double (nullable = true)
#  |-- 1831: double (nullable = true)
#  |-- 1830: double (nullable = true)
#  |-- 1829: double (nullable = true)
#  |-- 1828: double (nullable = true)
#  |-- 1827: double (nullable = true)
#  |-- 1826: double (nullable = true)
#  |-- 1825: double (nullable = true)
#  |-- 1824: double (nullable = true)
#  |-- 1823: double (nullable = true)
#  |-- 1822: double (nullable = true)
#  |-- 1821: double (nullable = true)
#  |-- 1820: double (nullable = true)
#  |-- 1819: double (nullable = true)
#  |-- 1818: double (nullable = true)
#  |-- 1817: double (nullable = true)
#  |-- 1816: double (nullable = true)
#  |-- 1815: double (nullable = true)
#  |-- 1814: double (nullable = true)
#  |-- 1813: double (nullable = true)
#  |-- 1812: double (nullable = true)
#  |-- 1811: double (nullable = true)
#  |-- 1810: double (nullable = true)
#  |-- 1809: double (nullable = true)
#  |-- 1808: double (nullable = true)
#  |-- 1807: double (nullable = true)
#  |-- 1806: double (nullable = true)
#  |-- 1805: double (nullable = true)
#  |-- 1804: double (nullable = true)
#  |-- 1803: double (nullable = true)
#  |-- 1802: double (nullable = true)
#  |-- 1801: double (nullable = true)
#  |-- 1800: double (nullable = true)
#  |-- 1799: double (nullable = true)
#  |-- 1798: double (nullable = true)
#  |-- 1797: double (nullable = true)
#  |-- 1796: double (nullable = true)
#  |-- 1795: double (nullable = true)
#  |-- 1794: double (nullable = true)
#  |-- 1793: double (nullable = true)
#  |-- 1792: double (nullable = true)
#  |-- 1791: double (nullable = true)
#  |-- 1790: double (nullable = true)
#  |-- 1789: double (nullable = true)
#  |-- 1788: double (nullable = true)
#  |-- 1787: double (nullable = true)
#  |-- 1786: double (nullable = true)
#  |-- 1785: double (nullable = true)
#  |-- 1784: double (nullable = true)
#  |-- 1783: double (nullable = true)
#  |-- 1782: double (nullable = true)
#  |-- 1781: double (nullable = true)
#  |-- 1780: double (nullable = true)
#  |-- 1779: double (nullable = true)
#  |-- 1778: double (nullable = true)
#  |-- 1777: double (nullable = true)
#  |-- 1776: double (nullable = true)
#  |-- 1775: double (nullable = true)
#  |-- 1774: double (nullable = true)
#  |-- 1773: double (nullable = true)
#  |-- 1772: double (nullable = true)
#  |-- 1771: double (nullable = true)
#  |-- 1770: double (nullable = true)
#  |-- 1769: double (nullable = true)
#  |-- 1768: double (nullable = true)
#  |-- 1767: double (nullable = true)
#  |-- 1766: double (nullable = true)
#  |-- 1765: double (nullable = true)
#  |-- 1764: double (nullable = true)
#  |-- 1763: double (nullable = true)
#  |-- 1762: double (nullable = true)
#  |-- 1761: double (nullable = true)
#  |-- 1760: double (nullable = true)
#  |-- 1759: double (nullable = true)
#  |-- 1758: double (nullable = true)
#  |-- 1757: double (nullable = true)
#  |-- 1756: double (nullable = true)
#  |-- 1755: double (nullable = true)
#  |-- 1754: double (nullable = true)
#  |-- 1753: double (nullable = true)
#  |-- 1752: double (nullable = true)
#  |-- 1751: double (nullable = true)
#  |-- 1750: double (nullable = true)
#  |-- 1749: double (nullable = true)
#  |-- 1748: double (nullable = true)
#  |-- 1747: double (nullable = true)
#  |-- 1746: double (nullable = true)
#  |-- 1745: double (nullable = true)
#  |-- 1744: double (nullable = true)
#  |-- 1743: double (nullable = true)
#  |-- 1742: double (nullable = true)
#  |-- 1741: double (nullable = true)
#  |-- 1740: double (nullable = true)
#  |-- 1739: double (nullable = true)
#  |-- 1738: double (nullable = true)
#  |-- 1737: double (nullable = true)
#  |-- 1736: double (nullable = true)
#  |-- 1735: double (nullable = true)
#  |-- 1734: double (nullable = true)
#  |-- 1733: double (nullable = true)
#  |-- 1732: double (nullable = true)
#  |-- 1731: double (nullable = true)
#  |-- 1730: double (nullable = true)
#  |-- 1729: double (nullable = true)
#  |-- 1728: double (nullable = true)
#  |-- 1727: double (nullable = true)
#  |-- 1726: double (nullable = true)
#  |-- 1725: double (nullable = true)
#  |-- 1724: double (nullable = true)
#  |-- 1723: double (nullable = true)
#  |-- 1722: double (nullable = true)
#  |-- 1721: double (nullable = true)
#  |-- 1720: double (nullable = true)
#  |-- 1719: double (nullable = true)
#  |-- 1718: double (nullable = true)
#  |-- 1717: double (nullable = true)
#  |-- 1716: double (nullable = true)
#  |-- 1715: double (nullable = true)
#  |-- 1714: double (nullable = true)
#  |-- 1713: double (nullable = true)
#  |-- 1712: double (nullable = true)
#  |-- 1711: double (nullable = true)
#  |-- 1710: double (nullable = true)
#  |-- 1709: double (nullable = true)
#  |-- 1708: double (nullable = true)
#  |-- 1707: double (nullable = true)
#  |-- 1706: double (nullable = true)
#  |-- 1705: double (nullable = true)
#  |-- 1704: double (nullable = true)
#  |-- 1703: double (nullable = true)
#  |-- 1702: double (nullable = true)
#  |-- 1701: double (nullable = true)
#  |-- 1700: double (nullable = true)
#  |-- 1699: double (nullable = true)
#  |-- 1698: double (nullable = true)
#  |-- 1697: double (nullable = true)
#  |-- 1696: double (nullable = true)
#  |-- 1695: double (nullable = true)
#  |-- 1694: double (nullable = true)
#  |-- 1693: double (nullable = true)
#  |-- 1692: double (nullable = true)
#  |-- 1691: double (nullable = true)
#  |-- 1690: double (nullable = true)
#  |-- 1689: double (nullable = true)
#  |-- 1688: double (nullable = true)
#  |-- 1687: double (nullable = true)
#  |-- 1686: double (nullable = true)
#  |-- 1685: double (nullable = true)
#  |-- 1684: double (nullable = true)
#  |-- 1683: double (nullable = true)
#  |-- 1682: double (nullable = true)
#  |-- 1681: double (nullable = true)
#  |-- 1680: double (nullable = true)
#  |-- 1679: double (nullable = true)
#  |-- 1678: double (nullable = true)
#  |-- 1677: double (nullable = true)
#  |-- 1676: double (nullable = true)
#  |-- 1675: double (nullable = true)
#  |-- 1674: double (nullable = true)
#  |-- 1673: double (nullable = true)
#  |-- 1672: double (nullable = true)
#  |-- 1671: double (nullable = true)
#  |-- 1670: double (nullable = true)
#  |-- 1669: double (nullable = true)
#  |-- 1668: double (nullable = true)
#  |-- 1667: double (nullable = true)
#  |-- 1666: double (nullable = true)
#  |-- 1665: double (nullable = true)
#  |-- 1664: double (nullable = true)
#  |-- 1663: double (nullable = true)
#  |-- 1662: double (nullable = true)
#  |-- 1661: double (nullable = true)
#  |-- 1660: double (nullable = true)
#  |-- 1659: double (nullable = true)
#  |-- 1658: double (nullable = true)
#  |-- 1657: double (nullable = true)
#  |-- 1656: double (nullable = true)
#  |-- 1655: double (nullable = true)
#  |-- 1654: double (nullable = true)
#  |-- 1653: double (nullable = true)
#  |-- 1652: double (nullable = true)
#  |-- 1651: double (nullable = true)
#  |-- 1650: double (nullable = true)
#  |-- 1649: double (nullable = true)
#  |-- 1648: double (nullable = true)
#  |-- 1647: double (nullable = true)
#  |-- 1646: double (nullable = true)
#  |-- 1645: double (nullable = true)
#  |-- 1644: double (nullable = true)
#  |-- 1643: double (nullable = true)
#  |-- 1642: double (nullable = true)
#  |-- 1641: double (nullable = true)
#  |-- 1640: double (nullable = true)
#  |-- 1639: double (nullable = true)
#  |-- 1638: double (nullable = true)
#  |-- 1637: double (nullable = true)
#  |-- 1636: double (nullable = true)
#  |-- 1635: double (nullable = true)
#  |-- 1634: double (nullable = true)
#  |-- 1633: double (nullable = true)
#  |-- 1632: double (nullable = true)
#  |-- 1631: double (nullable = true)
#  |-- 1630: double (nullable = true)
#  |-- 1629: double (nullable = true)
#  |-- 1628: double (nullable = true)
#  |-- 1627: double (nullable = true)
#  |-- 1626: double (nullable = true)
#  |-- 1625: double (nullable = true)
#  |-- 1624: double (nullable = true)
#  |-- 1623: double (nullable = true)
#  |-- 1622: double (nullable = true)
#  |-- 1621: double (nullable = true)
#  |-- 1620: double (nullable = true)
#  |-- 1619: double (nullable = true)
#  |-- 1618: double (nullable = true)
#  |-- 1617: double (nullable = true)
#  |-- 1616: double (nullable = true)
#  |-- 1615: double (nullable = true)
#  |-- 1614: double (nullable = true)
#  |-- 1613: double (nullable = true)
#  |-- 1612: double (nullable = true)
#  |-- 1611: double (nullable = true)
#  |-- 1610: double (nullable = true)
#  |-- 1609: double (nullable = true)
#  |-- 1608: double (nullable = true)
#  |-- 1607: double (nullable = true)
#  |-- 1606: double (nullable = true)
#  |-- 1605: double (nullable = true)
#  |-- 1604: double (nullable = true)
#  |-- 1603: double (nullable = true)
#  |-- 1602: double (nullable = true)
#  |-- 1601: double (nullable = true)
#  |-- 1600: double (nullable = true)
#  |-- 1599: double (nullable = true)
#  |-- 1598: double (nullable = true)
#  |-- 1597: double (nullable = true)
#  |-- 1596: double (nullable = true)
#  |-- 1595: double (nullable = true)
#  |-- 1594: double (nullable = true)
#  |-- 1593: double (nullable = true)
#  |-- 1592: double (nullable = true)
#  |-- 1591: double (nullable = true)
#  |-- 1590: double (nullable = true)
#  |-- 1589: double (nullable = true)
#  |-- 1588: double (nullable = true)
#  |-- 1587: double (nullable = true)
#  |-- 1586: double (nullable = true)
#  |-- 1585: double (nullable = true)
#  |-- 1584: double (nullable = true)
#  |-- 1583: double (nullable = true)
#  |-- 1582: double (nullable = true)
#  |-- 1581: double (nullable = true)
#  |-- 1580: double (nullable = true)
#  |-- 1579: double (nullable = true)
#  |-- 1578: double (nullable = true)
#  |-- 1577: double (nullable = true)
#  |-- 1576: double (nullable = true)
#  |-- 1575: double (nullable = true)
#  |-- 1574: double (nullable = true)
#  |-- 1573: double (nullable = true)
#  |-- 1572: double (nullable = true)
#  |-- 1571: double (nullable = true)
#  |-- 1570: double (nullable = true)
#  |-- 1569: double (nullable = true)
#  |-- 1568: double (nullable = true)
#  |-- 1567: double (nullable = true)
#  |-- 1566: double (nullable = true)
#  |-- 1565: double (nullable = true)
#  |-- 1564: double (nullable = true)
#  |-- 1563: double (nullable = true)
#  |-- 1562: double (nullable = true)
#  |-- 1561: double (nullable = true)
#  |-- 1560: double (nullable = true)
#  |-- 1559: double (nullable = true)
#  |-- 1558: double (nullable = true)
#  |-- 1557: double (nullable = true)
#  |-- 1556: double (nullable = true)
#  |-- 1555: double (nullable = true)
#  |-- 1554: double (nullable = true)
#  |-- 1553: double (nullable = true)
#  |-- 1552: double (nullable = true)
#  |-- 1551: double (nullable = true)
#  |-- 1550: double (nullable = true)
#  |-- 1549: double (nullable = true)
#  |-- 1548: double (nullable = true)
#  |-- 1547: double (nullable = true)
#  |-- 1546: double (nullable = true)
#  |-- 1545: double (nullable = true)
#  |-- 1544: double (nullable = true)
#  |-- 1543: double (nullable = true)
#  |-- 1542: double (nullable = true)
#  |-- 1541: double (nullable = true)
#  |-- 1540: double (nullable = true)
#  |-- 1539: double (nullable = true)
#  |-- 1538: double (nullable = true)
#  |-- 1537: double (nullable = true)
#  |-- 1536: double (nullable = true)
#  |-- 1535: double (nullable = true)
#  |-- 1534: double (nullable = true)
#  |-- 1533: double (nullable = true)
#  |-- 1532: double (nullable = true)
#  |-- 1531: double (nullable = true)
#  |-- 1530: double (nullable = true)
#  |-- 1529: double (nullable = true)
#  |-- 1528: double (nullable = true)
#  |-- 1527: double (nullable = true)
#  |-- 1526: double (nullable = true)
#  |-- 1525: double (nullable = true)
#  |-- 1524: double (nullable = true)
#  |-- 1523: double (nullable = true)
#  |-- 1522: double (nullable = true)
#  |-- 1521: double (nullable = true)
#  |-- 1520: double (nullable = true)
#  |-- 1519: double (nullable = true)
#  |-- 1518: double (nullable = true)
#  |-- 1517: double (nullable = true)
#  |-- 1516: double (nullable = true)
#  |-- 1515: double (nullable = true)
#  |-- 1514: double (nullable = true)
#  |-- 1513: double (nullable = true)
#  |-- 1512: double (nullable = true)
#  |-- 1511: double (nullable = true)
#  |-- 1510: double (nullable = true)
#  |-- 1509: double (nullable = true)
#  |-- 1508: double (nullable = true)
#  |-- 1507: double (nullable = true)
#  |-- 1506: double (nullable = true)
#  |-- 1505: double (nullable = true)
#  |-- 1504: double (nullable = true)
#  |-- 1503: double (nullable = true)
#  |-- 1502: double (nullable = true)
#  |-- 1501: double (nullable = true)
#  |-- 1500: double (nullable = true)
#  |-- 1499: double (nullable = true)
#  |-- 1498: double (nullable = true)
#  |-- 1497: double (nullable = true)
#  |-- 1496: double (nullable = true)
#  |-- 1495: double (nullable = true)
#  |-- 1494: double (nullable = true)
#  |-- 1493: double (nullable = true)
#  |-- 1492: double (nullable = true)
#  |-- 1491: double (nullable = true)
#  |-- 1490: double (nullable = true)
#  |-- 1489: double (nullable = true)
#  |-- 1488: double (nullable = true)
#  |-- 1487: double (nullable = true)
#  |-- 1486: double (nullable = true)
#  |-- 1485: double (nullable = true)
#  |-- 1484: double (nullable = true)
#  |-- 1483: double (nullable = true)
#  |-- 1482: double (nullable = true)
#  |-- 1481: double (nullable = true)
#  |-- 1480: double (nullable = true)
#  |-- 1479: double (nullable = true)
#  |-- 1478: double (nullable = true)
#  |-- 1477: double (nullable = true)
#  |-- 1476: double (nullable = true)
#  |-- 1475: double (nullable = true)
#  |-- 1474: double (nullable = true)
#  |-- 1473: double (nullable = true)
#  |-- 1472: double (nullable = true)
#  |-- 1471: double (nullable = true)
#  |-- 1470: double (nullable = true)
#  |-- 1469: double (nullable = true)
#  |-- 1468: double (nullable = true)
#  |-- 1467: double (nullable = true)
#  |-- 1466: double (nullable = true)
#  |-- 1465: double (nullable = true)
#  |-- 1464: double (nullable = true)
#  |-- 1463: double (nullable = true)
#  |-- 1462: double (nullable = true)
#  |-- 1461: double (nullable = true)
#  |-- 1460: double (nullable = true)
#  |-- 1459: double (nullable = true)
#  |-- 1458: double (nullable = true)
#  |-- 1457: double (nullable = true)
#  |-- 1456: double (nullable = true)
#  |-- 1455: double (nullable = true)
#  |-- 1454: double (nullable = true)
#  |-- 1453: double (nullable = true)
#  |-- 1452: double (nullable = true)
#  |-- 1451: double (nullable = true)
#  |-- 1450: double (nullable = true)
#  |-- 1449: double (nullable = true)
#  |-- 1448: double (nullable = true)
#  |-- 1447: double (nullable = true)
#  |-- 1446: double (nullable = true)
#  |-- 1445: double (nullable = true)
#  |-- 1444: double (nullable = true)
#  |-- 1443: double (nullable = true)
#  |-- 1442: double (nullable = true)
#  |-- 1441: double (nullable = true)
#  |-- 1440: double (nullable = true)
#  |-- 1439: double (nullable = true)
#  |-- 1438: double (nullable = true)
#  |-- 1437: double (nullable = true)
#  |-- 1436: double (nullable = true)
#  |-- 1435: double (nullable = true)
#  |-- 1434: double (nullable = true)
#  |-- 1433: double (nullable = true)
#  |-- 1432: double (nullable = true)
#  |-- 1431: double (nullable = true)
#  |-- 1430: double (nullable = true)
#  |-- 1429: double (nullable = true)
#  |-- 1428: double (nullable = true)
#  |-- 1427: double (nullable = true)
#  |-- 1426: double (nullable = true)
#  |-- 1425: double (nullable = true)
#  |-- 1424: double (nullable = true)
#  |-- 1423: double (nullable = true)
#  |-- 1422: double (nullable = true)
#  |-- 1421: double (nullable = true)
#  |-- 1420: double (nullable = true)
#  |-- 1419: double (nullable = true)
#  |-- 1418: double (nullable = true)
#  |-- 1417: double (nullable = true)
#  |-- 1416: double (nullable = true)
#  |-- 1415: double (nullable = true)
#  |-- 1414: double (nullable = true)
#  |-- 1413: double (nullable = true)
#  |-- 1412: double (nullable = true)
#  |-- 1411: double (nullable = true)
#  |-- 1410: double (nullable = true)
#  |-- 1409: double (nullable = true)
#  |-- 1408: double (nullable = true)
#  |-- 1407: double (nullable = true)
#  |-- 1406: double (nullable = true)
#  |-- 1405: double (nullable = true)
#  |-- 1404: double (nullable = true)
#  |-- 1403: double (nullable = true)
#  |-- 1402: double (nullable = true)
#  |-- 1401: double (nullable = true)
#  |-- 1400: double (nullable = true)
#  |-- 1399: double (nullable = true)
#  |-- 1398: double (nullable = true)
#  |-- 1397: double (nullable = true)
#  |-- 1396: double (nullable = true)
#  |-- 1395: double (nullable = true)
#  |-- 1394: double (nullable = true)
#  |-- 1393: double (nullable = true)
#  |-- 1392: double (nullable = true)
#  |-- 1391: double (nullable = true)
#  |-- 1390: double (nullable = true)
#  |-- 1389: double (nullable = true)
#  |-- 1388: double (nullable = true)
#  |-- 1387: double (nullable = true)
#  |-- 1386: double (nullable = true)
#  |-- 1385: double (nullable = true)
#  |-- 1384: double (nullable = true)
#  |-- 1383: double (nullable = true)
#  |-- 1382: double (nullable = true)
#  |-- 1381: double (nullable = true)
#  |-- 1380: double (nullable = true)
#  |-- 1379: double (nullable = true)
#  |-- 1378: double (nullable = true)
#  |-- 1377: double (nullable = true)
#  |-- 1376: double (nullable = true)
#  |-- 1375: double (nullable = true)
#  |-- 1374: double (nullable = true)
#  |-- 1373: double (nullable = true)
#  |-- 1372: double (nullable = true)
#  |-- 1371: double (nullable = true)
#  |-- 1370: double (nullable = true)
#  |-- 1369: double (nullable = true)
#  |-- 1368: double (nullable = true)
#  |-- 1367: double (nullable = true)
#  |-- 1366: double (nullable = true)
#  |-- 1365: double (nullable = true)
#  |-- 1364: double (nullable = true)
#  |-- 1363: double (nullable = true)
#  |-- 1362: double (nullable = true)
#  |-- 1361: double (nullable = true)
#  |-- 1360: double (nullable = true)
#  |-- 1359: double (nullable = true)
#  |-- 1358: double (nullable = true)
#  |-- 1357: double (nullable = true)
#  |-- 1356: double (nullable = true)
#  |-- 1355: double (nullable = true)
#  |-- 1354: double (nullable = true)
#  |-- 1353: double (nullable = true)
#  |-- 1352: double (nullable = true)
#  |-- 1351: double (nullable = true)
#  |-- 1350: double (nullable = true)
#  |-- 1349: double (nullable = true)
#  |-- 1348: double (nullable = true)
#  |-- 1347: double (nullable = true)
#  |-- 1346: double (nullable = true)
#  |-- 1345: double (nullable = true)
#  |-- 1344: double (nullable = true)
#  |-- 1343: double (nullable = true)
#  |-- 1342: double (nullable = true)
#  |-- 1341: double (nullable = true)
#  |-- 1340: double (nullable = true)
#  |-- 1339: double (nullable = true)
#  |-- 1338: double (nullable = true)
#  |-- 1337: double (nullable = true)
#  |-- 1336: double (nullable = true)
#  |-- 1335: double (nullable = true)
#  |-- 1334: double (nullable = true)
#  |-- 1333: double (nullable = true)
#  |-- 1332: double (nullable = true)
#  |-- 1331: double (nullable = true)
#  |-- 1330: double (nullable = true)
#  |-- 1329: double (nullable = true)
#  |-- 1328: double (nullable = true)
#  |-- 1327: double (nullable = true)
#  |-- 1326: double (nullable = true)
#  |-- 1325: double (nullable = true)
#  |-- 1324: double (nullable = true)
#  |-- 1323: double (nullable = true)
#  |-- 1322: double (nullable = true)
#  |-- 1321: double (nullable = true)
#  |-- 1320: double (nullable = true)
#  |-- 1319: double (nullable = true)
#  |-- 1318: double (nullable = true)
#  |-- 1317: double (nullable = true)
#  |-- 1316: double (nullable = true)
#  |-- 1315: double (nullable = true)
#  |-- 1314: double (nullable = true)
#  |-- 1313: double (nullable = true)
#  |-- 1312: double (nullable = true)
#  |-- 1311: double (nullable = true)
#  |-- 1310: double (nullable = true)
#  |-- 1309: double (nullable = true)
#  |-- 1308: double (nullable = true)
#  |-- 1307: double (nullable = true)
#  |-- 1306: double (nullable = true)
#  |-- 1305: double (nullable = true)
#  |-- 1304: double (nullable = true)
#  |-- 1303: double (nullable = true)
#  |-- 1302: double (nullable = true)
#  |-- 1301: double (nullable = true)
#  |-- 1300: double (nullable = true)
#  |-- 1299: double (nullable = true)
#  |-- 1298: double (nullable = true)
#  |-- 1297: double (nullable = true)
#  |-- 1296: double (nullable = true)
#  |-- 1295: double (nullable = true)
#  |-- 1294: double (nullable = true)
#  |-- 1293: double (nullable = true)
#  |-- 1292: double (nullable = true)
#  |-- 1291: double (nullable = true)
#  |-- 1290: double (nullable = true)
#  |-- 1289: double (nullable = true)
#  |-- 1288: double (nullable = true)
#  |-- 1287: double (nullable = true)
#  |-- 1286: double (nullable = true)
#  |-- 1285: double (nullable = true)
#  |-- 1284: double (nullable = true)
#  |-- 1283: double (nullable = true)
#  |-- 1282: double (nullable = true)
#  |-- 1281: double (nullable = true)
#  |-- 1280: double (nullable = true)
#  |-- 1279: double (nullable = true)
#  |-- 1278: double (nullable = true)
#  |-- 1277: double (nullable = true)
#  |-- 1276: double (nullable = true)
#  |-- 1275: double (nullable = true)
#  |-- 1274: double (nullable = true)
#  |-- 1273: double (nullable = true)
#  |-- 1272: double (nullable = true)
#  |-- 1271: double (nullable = true)
#  |-- 1270: double (nullable = true)
#  |-- 1269: double (nullable = true)
#  |-- 1268: double (nullable = true)
#  |-- 1267: double (nullable = true)
#  |-- 1266: double (nullable = true)
#  |-- 1265: double (nullable = true)
#  |-- 1264: double (nullable = true)
#  |-- 1263: double (nullable = true)
#  |-- 1262: double (nullable = true)
#  |-- 1261: double (nullable = true)
#  |-- 1260: double (nullable = true)
#  |-- 1259: double (nullable = true)
#  |-- 1258: double (nullable = true)
#  |-- 1257: double (nullable = true)
#  |-- 1256: double (nullable = true)
#  |-- 1255: double (nullable = true)
#  |-- 1254: double (nullable = true)
#  |-- 1253: double (nullable = true)
#  |-- 1252: double (nullable = true)
#  |-- 1251: double (nullable = true)
#  |-- 1250: double (nullable = true)
#  |-- 1249: double (nullable = true)
#  |-- 1248: double (nullable = true)
#  |-- 1247: double (nullable = true)
#  |-- 1246: double (nullable = true)
#  |-- 1245: double (nullable = true)
#  |-- 1244: double (nullable = true)
#  |-- 1243: double (nullable = true)
#  |-- 1242: double (nullable = true)
#  |-- 1241: double (nullable = true)
#  |-- 1240: double (nullable = true)
#  |-- 1239: double (nullable = true)
#  |-- 1238: double (nullable = true)
#  |-- 1237: double (nullable = true)
#  |-- 1236: double (nullable = true)
#  |-- 1235: double (nullable = true)
#  |-- 1234: double (nullable = true)
#  |-- 1233: double (nullable = true)
#  |-- 1232: double (nullable = true)
#  |-- 1231: double (nullable = true)
#  |-- 1230: double (nullable = true)
#  |-- 1229: double (nullable = true)
#  |-- 1228: double (nullable = true)
#  |-- 1227: double (nullable = true)
#  |-- 1226: double (nullable = true)
#  |-- 1225: double (nullable = true)
#  |-- 1224: double (nullable = true)
#  |-- 1223: double (nullable = true)
#  |-- 1222: double (nullable = true)
#  |-- 1221: double (nullable = true)
#  |-- 1220: double (nullable = true)
#  |-- 1219: double (nullable = true)
#  |-- 1218: double (nullable = true)
#  |-- 1217: double (nullable = true)
#  |-- 1216: double (nullable = true)
#  |-- 1215: double (nullable = true)
#  |-- 1214: double (nullable = true)
#  |-- 1213: double (nullable = true)
#  |-- 1212: double (nullable = true)
#  |-- 1211: double (nullable = true)
#  |-- 1210: double (nullable = true)
#  |-- 1209: double (nullable = true)
#  |-- 1208: double (nullable = true)
#  |-- 1207: double (nullable = true)
#  |-- 1206: double (nullable = true)
#  |-- 1205: double (nullable = true)
#  |-- 1204: double (nullable = true)
#  |-- 1203: double (nullable = true)
#  |-- 1202: double (nullable = true)
#  |-- 1201: double (nullable = true)
#  |-- 1200: double (nullable = true)
#  |-- 1199: double (nullable = true)
#  |-- 1198: double (nullable = true)
#  |-- 1197: double (nullable = true)
#  |-- 1196: double (nullable = true)
#  |-- 1195: double (nullable = true)
#  |-- 1194: double (nullable = true)
#  |-- 1193: double (nullable = true)
#  |-- 1192: double (nullable = true)
#  |-- 1191: double (nullable = true)
#  |-- 1190: double (nullable = true)
#  |-- 1189: double (nullable = true)
#  |-- 1188: double (nullable = true)
#  |-- 1187: double (nullable = true)
#  |-- 1186: double (nullable = true)
#  |-- 1185: double (nullable = true)
#  |-- 1184: double (nullable = true)
#  |-- 1183: double (nullable = true)
#  |-- 1182: double (nullable = true)
#  |-- 1181: double (nullable = true)
#  |-- 1180: double (nullable = true)
#  |-- 1179: double (nullable = true)
#  |-- 1178: double (nullable = true)
#  |-- 1177: double (nullable = true)
#  |-- 1176: double (nullable = true)
#  |-- 1175: double (nullable = true)
#  |-- 1174: double (nullable = true)
#  |-- 1173: double (nullable = true)
#  |-- 1172: double (nullable = true)
#  |-- 1171: double (nullable = true)
#  |-- 1170: double (nullable = true)
#  |-- 1169: double (nullable = true)
#  |-- 1168: double (nullable = true)
#  |-- 1167: double (nullable = true)
#  |-- 1166: double (nullable = true)
#  |-- 1165: double (nullable = true)
#  |-- 1164: double (nullable = true)
#  |-- 1163: double (nullable = true)
#  |-- 1162: double (nullable = true)
#  |-- 1161: double (nullable = true)
#  |-- 1160: double (nullable = true)
#  |-- 1159: double (nullable = true)
#  |-- 1158: double (nullable = true)
#  |-- 1157: double (nullable = true)
#  |-- 1156: double (nullable = true)
#  |-- 1155: double (nullable = true)
#  |-- 1154: double (nullable = true)
#  |-- 1153: double (nullable = true)
#  |-- 1152: double (nullable = true)
#  |-- 1151: double (nullable = true)
#  |-- 1150: double (nullable = true)
#  |-- 1149: double (nullable = true)
#  |-- 1148: double (nullable = true)
#  |-- 1147: double (nullable = true)
#  |-- 1146: double (nullable = true)
#  |-- 1145: double (nullable = true)
#  |-- 1144: double (nullable = true)
#  |-- 1143: double (nullable = true)
#  |-- 1142: double (nullable = true)
#  |-- 1141: double (nullable = true)
#  |-- 1140: double (nullable = true)
#  |-- 1139: double (nullable = true)
#  |-- 1138: double (nullable = true)
#  |-- 1137: double (nullable = true)
#  |-- 1136: double (nullable = true)
#  |-- 1135: double (nullable = true)
#  |-- 1134: double (nullable = true)
#  |-- 1133: double (nullable = true)
#  |-- 1132: double (nullable = true)
#  |-- 1131: double (nullable = true)
#  |-- 1130: double (nullable = true)
#  |-- 1129: double (nullable = true)
#  |-- 1128: double (nullable = true)
#  |-- 1127: double (nullable = true)
#  |-- 1126: double (nullable = true)
#  |-- 1125: double (nullable = true)
#  |-- 1124: double (nullable = true)
#  |-- 1123: double (nullable = true)
#  |-- 1122: double (nullable = true)
#  |-- 1121: double (nullable = true)
#  |-- 1120: double (nullable = true)
#  |-- 1119: double (nullable = true)
#  |-- 1118: double (nullable = true)
#  |-- 1117: double (nullable = true)
#  |-- 1116: double (nullable = true)
#  |-- 1115: double (nullable = true)
#  |-- 1114: double (nullable = true)
#  |-- 1113: double (nullable = true)
#  |-- 1112: double (nullable = true)
#  |-- 1111: double (nullable = true)
#  |-- 1110: double (nullable = true)
#  |-- 1109: double (nullable = true)
#  |-- 1108: double (nullable = true)
#  |-- 1107: double (nullable = true)
#  |-- 1106: double (nullable = true)
#  |-- 1105: double (nullable = true)
#  |-- 1104: double (nullable = true)
#  |-- 1103: double (nullable = true)
#  |-- 1102: double (nullable = true)
#  |-- 1101: double (nullable = true)
#  |-- 1100: double (nullable = true)
#  |-- 1099: double (nullable = true)
#  |-- 1098: double (nullable = true)
#  |-- 1097: double (nullable = true)
#  |-- 1096: double (nullable = true)
#  |-- 1095: double (nullable = true)
#  |-- 1094: double (nullable = true)
#  |-- 1093: double (nullable = true)
#  |-- 1092: double (nullable = true)
#  |-- 1091: double (nullable = true)
#  |-- 1090: double (nullable = true)
#  |-- 1089: double (nullable = true)
#  |-- 1088: double (nullable = true)
#  |-- 1087: double (nullable = true)
#  |-- 1086: double (nullable = true)
#  |-- 1085: double (nullable = true)
#  |-- 1084: double (nullable = true)
#  |-- 1083: double (nullable = true)
#  |-- 1082: double (nullable = true)
#  |-- 1081: double (nullable = true)
#  |-- 1080: double (nullable = true)
#  |-- 1079: double (nullable = true)
#  |-- 1078: double (nullable = true)
#  |-- 1077: double (nullable = true)
#  |-- 1076: double (nullable = true)
#  |-- 1075: double (nullable = true)
#  |-- 1074: double (nullable = true)
#  |-- 1073: double (nullable = true)
#  |-- 1072: double (nullable = true)
#  |-- 1071: double (nullable = true)
#  |-- 1070: double (nullable = true)
#  |-- 1069: double (nullable = true)
#  |-- 1068: double (nullable = true)
#  |-- 1067: double (nullable = true)
#  |-- 1066: double (nullable = true)
#  |-- 1065: double (nullable = true)
#  |-- 1064: double (nullable = true)
#  |-- 1063: double (nullable = true)
#  |-- 1062: double (nullable = true)
#  |-- 1061: double (nullable = true)
#  |-- 1060: double (nullable = true)
#  |-- 1059: double (nullable = true)
#  |-- 1058: double (nullable = true)
#  |-- 1057: double (nullable = true)
#  |-- 1056: double (nullable = true)
#  |-- 1055: double (nullable = true)
#  |-- 1054: double (nullable = true)
#  |-- 1053: double (nullable = true)
#  |-- 1052: double (nullable = true)
#  |-- 1051: double (nullable = true)
#  |-- 1050: double (nullable = true)
#  |-- 1049: double (nullable = true)
#  |-- 1048: double (nullable = true)
#  |-- 1047: double (nullable = true)
#  |-- 1046: double (nullable = true)
#  |-- 1045: double (nullable = true)
#  |-- 1044: double (nullable = true)
#  |-- 1043: double (nullable = true)
#  |-- 1042: double (nullable = true)
#  |-- 1041: double (nullable = true)
#  |-- 1040: double (nullable = true)
#  |-- 1039: double (nullable = true)
#  |-- 1038: double (nullable = true)
#  |-- 1037: double (nullable = true)
#  |-- 1036: double (nullable = true)
#  |-- 1035: double (nullable = true)
#  |-- 1034: double (nullable = true)
#  |-- 1033: double (nullable = true)
#  |-- 1032: double (nullable = true)
#  |-- 1031: double (nullable = true)
#  |-- 1030: double (nullable = true)
#  |-- 1029: double (nullable = true)
#  |-- 1028: double (nullable = true)
#  |-- 1027: double (nullable = true)
#  |-- 1026: double (nullable = true)
#  |-- 1025: double (nullable = true)
#  |-- 1024: double (nullable = true)
#  |-- 1023: double (nullable = true)
#  |-- 1022: double (nullable = true)
#  |-- 1021: double (nullable = true)
#  |-- 1020: double (nullable = true)
#  |-- 1019: double (nullable = true)
#  |-- 1018: double (nullable = true)
#  |-- 1017: double (nullable = true)
#  |-- 1016: double (nullable = true)
#  |-- 1015: double (nullable = true)
#  |-- 1014: double (nullable = true)
#  |-- 1013: double (nullable = true)
#  |-- 1012: double (nullable = true)
#  |-- 1011: double (nullable = true)
#  |-- 1010: double (nullable = true)
#  |-- 1009: double (nullable = true)
#  |-- 1008: double (nullable = true)
#  |-- 1007: double (nullable = true)
#  |-- 1006: double (nullable = true)
#  |-- 1005: double (nullable = true)
#  |-- 1004: double (nullable = true)
#  |-- 1003: double (nullable = true)
#  |-- 1002: double (nullable = true)
#  |-- 1001: double (nullable = true)
#  |-- 1000: double (nullable = true)
#  |-- 999: double (nullable = true)
#  |-- 998: double (nullable = true)
#  |-- 997: double (nullable = true)
#  |-- 996: double (nullable = true)
#  |-- 995: double (nullable = true)
#  |-- 994: double (nullable = true)
#  |-- 993: double (nullable = true)
#  |-- 992: double (nullable = true)
#  |-- 991: double (nullable = true)
#  |-- 990: double (nullable = true)
#  |-- 989: double (nullable = true)
#  |-- 988: double (nullable = true)
#  |-- 987: double (nullable = true)
#  |-- 986: double (nullable = true)
#  |-- 985: double (nullable = true)
#  |-- 984: double (nullable = true)
#  |-- 983: double (nullable = true)
#  |-- 982: double (nullable = true)
#  |-- 981: double (nullable = true)
#  |-- 980: double (nullable = true)
#  |-- 979: double (nullable = true)
#  |-- 978: double (nullable = true)
#  |-- 977: double (nullable = true)
#  |-- 976: double (nullable = true)
#  |-- 975: double (nullable = true)
#  |-- 974: double (nullable = true)
#  |-- 973: double (nullable = true)
#  |-- 972: double (nullable = true)
#  |-- 971: double (nullable = true)
#  |-- 970: double (nullable = true)
#  |-- 969: double (nullable = true)
#  |-- 968: double (nullable = true)
#  |-- 967: double (nullable = true)
#  |-- 966: double (nullable = true)
#  |-- 965: double (nullable = true)
#  |-- 964: double (nullable = true)
#  |-- 963: double (nullable = true)
#  |-- 962: double (nullable = true)
#  |-- 961: double (nullable = true)
#  |-- 960: double (nullable = true)
#  |-- 959: double (nullable = true)
#  |-- 958: double (nullable = true)
#  |-- 957: double (nullable = true)
#  |-- 956: double (nullable = true)
#  |-- 955: double (nullable = true)
#  |-- 954: double (nullable = true)
#  |-- 953: double (nullable = true)
#  |-- 952: double (nullable = true)
#  |-- 951: double (nullable = true)
#  |-- 950: double (nullable = true)
#  |-- 949: double (nullable = true)
#  |-- 948: double (nullable = true)
#  |-- 947: double (nullable = true)
#  |-- 946: double (nullable = true)
#  |-- 945: double (nullable = true)
#  |-- 944: double (nullable = true)
#  |-- 943: double (nullable = true)
#  |-- 942: double (nullable = true)
#  |-- 941: double (nullable = true)
#  |-- 940: double (nullable = true)
#  |-- 939: double (nullable = true)
#  |-- 938: double (nullable = true)
#  |-- 937: double (nullable = true)
#  |-- 936: double (nullable = true)
#  |-- 935: double (nullable = true)
#  |-- 934: double (nullable = true)
#  |-- 933: double (nullable = true)
#  |-- 932: double (nullable = true)
#  |-- 931: double (nullable = true)
#  |-- 930: double (nullable = true)
#  |-- 929: double (nullable = true)
#  |-- 928: double (nullable = true)
#  |-- 927: double (nullable = true)
#  |-- 926: double (nullable = true)
#  |-- 925: double (nullable = true)
#  |-- 924: double (nullable = true)
#  |-- 923: double (nullable = true)
#  |-- 922: double (nullable = true)
#  |-- 921: double (nullable = true)
#  |-- 920: double (nullable = true)
#  |-- 919: double (nullable = true)
#  |-- 918: double (nullable = true)
#  |-- 917: double (nullable = true)
#  |-- 916: double (nullable = true)
#  |-- 915: double (nullable = true)
#  |-- 914: double (nullable = true)
#  |-- 913: double (nullable = true)
#  |-- 912: double (nullable = true)
#  |-- 911: double (nullable = true)
#  |-- 910: double (nullable = true)
#  |-- 909: double (nullable = true)
#  |-- 908: double (nullable = true)
#  |-- 907: double (nullable = true)
#  |-- 906: double (nullable = true)
#  |-- 905: double (nullable = true)
#  |-- 904: double (nullable = true)
#  |-- 903: double (nullable = true)
#  |-- 902: double (nullable = true)
#  |-- 901: double (nullable = true)
#  |-- 900: double (nullable = true)
#  |-- 899: double (nullable = true)
#  |-- 898: double (nullable = true)
#  |-- 897: double (nullable = true)
#  |-- 896: double (nullable = true)
#  |-- 895: double (nullable = true)
#  |-- 894: double (nullable = true)
#  |-- 893: double (nullable = true)
#  |-- 892: double (nullable = true)
#  |-- 891: double (nullable = true)
#  |-- 890: double (nullable = true)
#  |-- 889: double (nullable = true)
#  |-- 888: double (nullable = true)
#  |-- 887: double (nullable = true)
#  |-- 886: double (nullable = true)
#  |-- 885: double (nullable = true)
#  |-- 884: double (nullable = true)
#  |-- 883: double (nullable = true)
#  |-- 882: double (nullable = true)
#  |-- 881: double (nullable = true)
#  |-- 880: double (nullable = true)
#  |-- 879: double (nullable = true)
#  |-- 878: double (nullable = true)
#  |-- 877: double (nullable = true)
#  |-- 876: double (nullable = true)
#  |-- 875: double (nullable = true)
#  |-- 874: double (nullable = true)
#  |-- 873: double (nullable = true)
#  |-- 872: double (nullable = true)
#  |-- 871: double (nullable = true)
#  |-- 870: double (nullable = true)
#  |-- 869: double (nullable = true)
#  |-- 868: double (nullable = true)
#  |-- 867: double (nullable = true)
#  |-- 866: double (nullable = true)
#  |-- 865: double (nullable = true)
#  |-- 864: double (nullable = true)
#  |-- 863: double (nullable = true)
#  |-- 862: double (nullable = true)
#  |-- 861: double (nullable = true)
#  |-- 860: double (nullable = true)
#  |-- 859: double (nullable = true)
#  |-- 858: double (nullable = true)
#  |-- 857: double (nullable = true)
#  |-- 856: double (nullable = true)
#  |-- 855: double (nullable = true)
#  |-- 854: double (nullable = true)
#  |-- 853: double (nullable = true)
#  |-- 852: double (nullable = true)
#  |-- 851: double (nullable = true)
#  |-- 850: double (nullable = true)
#  |-- 849: double (nullable = true)
#  |-- 848: double (nullable = true)
#  |-- 847: double (nullable = true)
#  |-- 846: double (nullable = true)
#  |-- 845: double (nullable = true)
#  |-- 844: double (nullable = true)
#  |-- 843: double (nullable = true)
#  |-- 842: double (nullable = true)
#  |-- 841: double (nullable = true)
#  |-- 840: double (nullable = true)
#  |-- 839: double (nullable = true)
#  |-- 838: double (nullable = true)
#  |-- 837: double (nullable = true)
#  |-- 836: double (nullable = true)
#  |-- 835: double (nullable = true)
#  |-- 834: double (nullable = true)
#  |-- 833: double (nullable = true)
#  |-- 832: double (nullable = true)
#  |-- 831: double (nullable = true)
#  |-- 830: double (nullable = true)
#  |-- 829: double (nullable = true)
#  |-- 828: double (nullable = true)
#  |-- 827: double (nullable = true)
#  |-- 826: double (nullable = true)
#  |-- 825: double (nullable = true)
#  |-- 824: double (nullable = true)
#  |-- 823: double (nullable = true)
#  |-- 822: double (nullable = true)
#  |-- 821: double (nullable = true)
#  |-- 820: double (nullable = true)
#  |-- 819: double (nullable = true)
#  |-- 818: double (nullable = true)
#  |-- 817: double (nullable = true)
#  |-- 816: double (nullable = true)
#  |-- 815: double (nullable = true)
#  |-- 814: double (nullable = true)
#  |-- 813: double (nullable = true)
#  |-- 812: double (nullable = true)
#  |-- 811: double (nullable = true)
#  |-- 810: double (nullable = true)
#  |-- 809: double (nullable = true)
#  |-- 808: double (nullable = true)
#  |-- 807: double (nullable = true)
#  |-- 806: double (nullable = true)
#  |-- 805: double (nullable = true)
#  |-- 804: double (nullable = true)
#  |-- 803: double (nullable = true)
#  |-- 802: double (nullable = true)
#  |-- 801: double (nullable = true)
#  |-- 800: double (nullable = true)
#  |-- 799: double (nullable = true)
#  |-- 798: double (nullable = true)
#  |-- 797: double (nullable = true)
#  |-- 796: double (nullable = true)
#  |-- 795: double (nullable = true)
#  |-- 794: double (nullable = true)
#  |-- 793: double (nullable = true)
#  |-- 792: double (nullable = true)
#  |-- 791: double (nullable = true)
#  |-- 790: double (nullable = true)
#  |-- 789: double (nullable = true)
#  |-- 788: double (nullable = true)
#  |-- 787: double (nullable = true)
#  |-- 786: double (nullable = true)
#  |-- 785: double (nullable = true)
#  |-- 784: double (nullable = true)
#  |-- 783: double (nullable = true)
#  |-- 782: double (nullable = true)
#  |-- 781: double (nullable = true)
#  |-- 780: double (nullable = true)
#  |-- 779: double (nullable = true)
#  |-- 778: double (nullable = true)
#  |-- 777: double (nullable = true)
#  |-- 776: double (nullable = true)
#  |-- 775: double (nullable = true)
#  |-- 774: double (nullable = true)
#  |-- 773: double (nullable = true)
#  |-- 772: double (nullable = true)
#  |-- 771: double (nullable = true)
#  |-- 770: double (nullable = true)
#  |-- 769: double (nullable = true)
#  |-- 768: double (nullable = true)
#  |-- 767: double (nullable = true)
#  |-- 766: double (nullable = true)
#  |-- 765: double (nullable = true)
#  |-- 764: double (nullable = true)
#  |-- 763: double (nullable = true)
#  |-- 762: double (nullable = true)
#  |-- 761: double (nullable = true)
#  |-- 760: double (nullable = true)
#  |-- 759: double (nullable = true)
#  |-- 758: double (nullable = true)
#  |-- 757: double (nullable = true)
#  |-- 756: double (nullable = true)
#  |-- 755: double (nullable = true)
#  |-- 754: double (nullable = true)
#  |-- 753: double (nullable = true)
#  |-- 752: double (nullable = true)
#  |-- 751: double (nullable = true)
#  |-- 750: double (nullable = true)
#  |-- 749: double (nullable = true)
#  |-- 748: double (nullable = true)
#  |-- 747: double (nullable = true)
#  |-- 746: double (nullable = true)
#  |-- 745: double (nullable = true)
#  |-- 744: double (nullable = true)
#  |-- 743: double (nullable = true)
#  |-- 742: double (nullable = true)
#  |-- 741: double (nullable = true)
#  |-- 740: double (nullable = true)
#  |-- 739: double (nullable = true)
#  |-- 738: double (nullable = true)
#  |-- 737: double (nullable = true)
#  |-- 736: double (nullable = true)
#  |-- 735: double (nullable = true)
#  |-- 734: double (nullable = true)
#  |-- 733: double (nullable = true)
#  |-- 732: double (nullable = true)
#  |-- 731: double (nullable = true)
#  |-- 730: double (nullable = true)
#  |-- 729: double (nullable = true)
#  |-- 728: double (nullable = true)
#  |-- 727: double (nullable = true)
#  |-- 726: double (nullable = true)
#  |-- 725: double (nullable = true)
#  |-- 724: double (nullable = true)
#  |-- 723: double (nullable = true)
#  |-- 722: double (nullable = true)
#  |-- 721: double (nullable = true)
#  |-- 720: double (nullable = true)
#  |-- 719: double (nullable = true)
#  |-- 718: double (nullable = true)
#  |-- 717: double (nullable = true)
#  |-- 716: double (nullable = true)
#  |-- 715: double (nullable = true)
#  |-- 714: double (nullable = true)
#  |-- 713: double (nullable = true)
#  |-- 712: double (nullable = true)
#  |-- 711: double (nullable = true)
#  |-- 710: double (nullable = true)
#  |-- 709: double (nullable = true)
#  |-- 708: double (nullable = true)
#  |-- 707: double (nullable = true)
#  |-- 706: double (nullable = true)
#  |-- 705: double (nullable = true)
#  |-- 704: double (nullable = true)
#  |-- 703: double (nullable = true)
#  |-- 702: double (nullable = true)
#  |-- 701: double (nullable = true)
#  |-- 700: double (nullable = true)
#  |-- 699: double (nullable = true)
#  |-- 698: double (nullable = true)
#  |-- 697: double (nullable = true)
#  |-- 696: double (nullable = true)
#  |-- 695: double (nullable = true)
#  |-- 694: double (nullable = true)
#  |-- 693: double (nullable = true)
#  |-- 692: double (nullable = true)
#  |-- 691: double (nullable = true)
#  |-- 690: double (nullable = true)
#  |-- 689: double (nullable = true)
#  |-- id: long (nullable = true)
#  |-- penicillin_concentration_g_l: double (nullable = false)

# %%
df_raman_predict = df_raman_new.toPandas()

# %%
df_raman_predict.shape
# Out:
# (7000, 1402)

# %%
# Calculate Derivative
df_raman_spectra = df_raman_predict.copy()
df_raman_test = df_raman_spectra
df_raman_test.drop("id", axis=1, inplace=True)
df_raman_test.drop("penicillin_concentration_g_l", axis=1, inplace=True)
rcbw = RangeCut(0, df_raman_test.shape[1])
data = rcbw.fit_transform(df_raman_test)
raman_df = pd.DataFrame(data)
lc = LinearCorrection()
spectra_baseline = lc.fit_transform(raman_df)
sgf = SavitzkyGolayFilter(window_size=15, polynomial_order=2)
spectra_norm = sgf.fit_transform(spectra_baseline)
nw = NorrisWilliams(window_size=15, gap_size=3, derivative_order=1)
spectra_derivative = pd.DataFrame(nw.fit_transform(spectra_norm))

# %%
# Create PLS Model
x = spectra_derivative

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
predicted_concentration = pls_model.predict(x_scaled)

# %%
df_raman_compare = pd.concat([df_raman_predict[["id","penicillin_concentration_g_l"]], pd.DataFrame({'predicted_penicillin_concentration': predicted_concentration})], axis=1)

# %%
df_raman_feature = spark.createDataFrame(df_raman_compare)

# %%
# define schema for T_RAMAN_PREDICT
predict_schema = T.StructType([
    T.StructField("id",T.IntegerType()),
    T.StructField("penicillin_concentration_g_l",T.DoubleType()),
    T.StructField("predicted_penicillin_concentration",T.DoubleType())
])

# %%
# add new sample context data to T_RAMAN_PREDICTION
print(f"About to insert new data to T_SAMPLE_CONTEXT")
df_raman_feature.write.format("bigquery") \
    .option("temporaryGcsBucket", BUCKET) \
    .option("table", PROJECT_ID+".test_schema.t_raman_prediction") \
    .option("createDisposition", "CREATE_IF_NEEDED") \
    .option("writeDisposition", "WRITE_TRUNCATE") \
    .option("schema", predict_schema.json()) \
    .mode("append") \
    .save()
# Out:
# About to insert new data to T_SAMPLE_CONTEXT

# %%
# Stop Local Standalone cluster
# !cd $SPARK_HOME && ./sbin/stop-master.sh
# Out:
# IOStream.flush timed out
# stopping org.apache.spark.deploy.master.Master

# %%
# Stop Local Standalone cluster
# !cd $SPARK_HOME && ./sbin/stop-worker.sh
# Out:
# 24/04/14 23:41:47 WARN StandaloneAppClient$ClientEndpoint: Connection to 127.0.0.1:7078 failed; waiting for master to reconnect...
# 24/04/14 23:41:47 WARN StandaloneSchedulerBackend: Disconnected from Spark cluster! Waiting for reconnection...
# 24/04/14 23:41:47 WARN StandaloneAppClient$ClientEndpoint: Connection to 127.0.0.1:7078 failed; waiting for master to reconnect...
# IOStream.flush timed out
# stopping org.apache.spark.deploy.worker.Worker
# 24/04/14 23:42:02 ERROR TaskSchedulerImpl: Lost executor 0 on 10.168.0.7: Remote RPC client disassociated. Likely due to containers exceeding thresholds, or network issues. Check driver logs for WARN messages.
# 24/04/14 23:42:02 WARN BlockManagerMasterEndpoint: No more replicas available for broadcast_4_python !
